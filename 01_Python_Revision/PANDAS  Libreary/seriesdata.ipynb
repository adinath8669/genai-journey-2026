# %%
import pandas as pd

data=[10,20,30,200,300]

# series=pd.Series(data)
series=pd.Series(data, index=["a","b","c","e","f"])

print(series)
# Out:
# a     10
# b     20
# c     30
# e    200
# f    300
# dtype: int64

# %%
series.loc["c"]=200

print(series)

print(series.iloc[1])
# Out:
# a     10
# b     20
# c    200
# e    200
# f    300
# dtype: int64
# 20

# %%
print(series[series>=200])
# Out:
# c    200
# e    200
# f    300
# dtype: int64

# %%
caloryes={"day 1" : 1750,"day 2" : 1700,"day 3" : 2500}

series2=pd.Series(caloryes)

print(caloryes)

# updat calaryes

series2.loc["day 2"]=1800

print(series2)
# Out:
# {'day 1': 1750, 'day 2': 1700, 'day 3': 2500}
# day 1    1750
# day 2    1800
# day 3    2500
# dtype: int64
